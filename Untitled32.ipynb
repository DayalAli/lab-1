# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
unzip =  'E-commerce Website Logs.csv'

# %%
df=pd.read_csv("E-commerce Website Logs.csv")
df
# Out:
# C:\Users\INDUS\AppData\Local\Temp\ipykernel_17488\3294065338.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("E-commerce Website Logs.csv")
#                   accessed_date  duration_(secs) network_protocol  \
# 0       2017-03-14 17:43:57.172             2533            TCP
# 1       2017-03-14 17:43:57.172             4034            TCP
# 2       2017-03-14 17:43:26.135             1525            TCP
# 3       2017-03-14 17:43:26.135             4572            TCP
# 4       2017-03-14 18:17:09.005             3652            TCP
# ...                         ...              ...              ...
# 172833  2017-03-16 11:42:01.298             4372            TCP
# 172834  2017-03-16 12:10:17.340             2167            TCP
# 172835  2017-03-16 12:10:17.340             2725            TCP
# 172836  2017-03-16 15:52:58.342             3728            TCP
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# accessed_date       0
# duration_(secs)     0
# network_protocol    0
# ip                  0
# bytes               0
# accessed_Ffom       0
# age                 0
# gender              0
# country             0
# membership          0
# language            0
# sales               0
# returned            0
# returned_amount     0
# pay_method          0
# dtype: int64

# %%
df.describe()
# Out:
#        duration_(secs)          bytes         sales  returned_amount
# count     99457.000000   99457.000000  99457.000000     99457.000000
# mean       3251.364328    1402.250621    360.273099        72.080813
# std        1011.849589    7484.018496    736.018297       361.073570
# min        1500.000000      28.000000      0.000000         0.000000
# 25%        2373.000000     250.000000      0.000000         0.000000
# 50%        3251.000000     579.000000     40.660000         0.000000
# 75%        4128.000000    2267.000000    244.550000         0.000000
# max        5000.000000  897983.000000  11199.968000      7999.980000

# %%
df=df.replace({'Credit Card': 0,'Debit Card': 1,'Cash': 2,'No': 1,'Yes': 2,'English': 1,'Spanish': 2,'Normal': 1,'Premium': 2,'CA': 1,'AR': 2,'PL': 3,'IN': 4,'KR': 5,'IT': 6,'CN': 7,'US': 8,'Male': 1,'Female': 2,'Chrome': 1,'Mozilla Firefox': 2,'Microsoft Edge': 3,'Safari': 4,'TCP': 1})

# %%
X = df.drop(['returned_amount', 'pay_method'], axis=1)

# %%
X
# Out:
#                  accessed_date  duration_(secs) network_protocol  \
# 0      2017-03-14 17:43:57.172             2533            TCP
# 1      2017-03-14 17:43:57.172             4034            TCP
# 2      2017-03-14 17:43:26.135             1525            TCP
# 3      2017-03-14 17:43:26.135             4572            TCP
# 4      2017-03-14 18:17:09.005             3652            TCP
# ...                        ...              ...              ...
# 99452  2017-03-19 02:56:59.288             3439            TCP
# 99453  2017-03-19 02:57:46.757             2479            TCP
# 99454  2017-03-19 02:57:46.757             4231            TCP
# 99455  2017-03-19 02:57:59.565             3807            TCP
# 99456  2017-03-19 02:57:59.565             4479            TCP
#
#                     ip   bytes accessed_Ffom age gender country membership  \
# 0         1.10.195.126   20100             1  28      2       1          1
# ...

# %%
y = df[['returned_amount', 'pay_method']]
y
# Out:
#        returned_amount pay_method
# 0                0.000          0
# 1                0.000          1
# 2                0.000          2
# 3                0.000          0
# 4                0.000          2
# ...                ...        ...
# 99452            0.000          1
# 99453            0.000          2
# 99454            0.000          0
# 99455         2700.765          0
# 99456            0.000          1
#
# [99457 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state = 42)

# %%
X_train
# Out:
#                  accessed_date  duration_(secs) network_protocol  \
# 506    2017-03-15 00:18:59.888             3483             HTTP
# 88289  2017-03-18 20:39:32.641             4942            TCP
# 77520  2017-03-18 09:09:31.312             1723            TCP
# 85865  2017-03-18 17:22:37.234             2881            TCP
# 57556  2017-03-17 16:19:32.206             4993            TCP
# ...                        ...              ...              ...
# 6265   2017-03-15 07:14:33.214             4121             HTTP
# 54886  2017-03-17 11:58:19.845             3167             HTTP
# 76820  2017-03-18 08:13:38.664             2238            TCP
# 860    2017-03-15 00:34:39.480             3081             HTTP
# 15795  2017-03-15 18:11:50.285             2694             HTTP
#
#                     ip  bytes accessed_Ffom age   gender country  \
# 506      5.230.154.209   2267   Android App  33        1      RU
# ...

# %%
y_train
# Out:
#        returned_amount pay_method
# 506             0.0000          0
# 88289           0.0000          2
# 77520         450.1275          2
# 85865           0.0000          0
# 57556           0.0000          2
# ...                ...        ...
# 6265            0.0000          0
# 54886           0.0000          2
# 76820           0.0000          2
# 860            83.7200          0
# 15795           0.0000          2
#
# [74592 rows x 2 columns]
